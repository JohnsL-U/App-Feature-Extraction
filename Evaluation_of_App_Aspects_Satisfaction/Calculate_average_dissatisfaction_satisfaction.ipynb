# %% [markdown]
# # Assign app name for each review

# %%
import pandas as pd
import re

# %%
data = pd.read_csv('final_file_combined_features.csv') 
df = pd.DataFrame(data, columns=['r_id', 'review', 'review_sentiment', 's_id', 'sentence', 'sentence_sentiment', 'feature', 'weight', 'rating'])

# %%
r_id_1 = df['r_id'].to_list()

# %%
print(r_id_1)

# %%
data = pd.read_csv('preprocessing_3.csv') 
df_2 = pd.DataFrame(data, columns=['r_id', 'app_name'])

# %%
df_2

# %%
unique_apps = df_2.drop_duplicates(subset=["r_id", "app_name"])
print(unique_apps)
# Out:
#       r_id  app_name
# 0        0   grubhub
# 22       1   grubhub
# 35       2   grubhub
# 44       3   grubhub
# 51       4   grubhub
# ...    ...       ...
# 8438  1340  doordash
# 8441  1341  doordash
# 8446  1342  doordash
# 8453  1343  doordash
# 8460  1344  doordash
#
# [1345 rows x 2 columns]

# %%
r_id_2 = unique_apps['r_id'].to_list()
app_name = unique_apps['app_name'].to_list()
# print(r_id_2)

# %%
table = {"app_name": [], "r_id": [], "review": [], "review_sentiment": [], "s_id": [], "sentence": [], "sentence_sentiment": [], "feature": [], 'weight': [], 'rating': []}

for x in range(len(df)):
    for y in range(len(unique_apps)):
        if r_id_1[x] == r_id_2[y]:
            table["app_name"].append(app_name[y])
            table["r_id"].append(r_id_1[x])
            table["review"].append(df['review'][x])
            table["review_sentiment"].append(df['review_sentiment'][x])
            table["s_id"].append(df['s_id'][x])
            table["sentence"].append(df['sentence'][x])
            table["sentence_sentiment"].append(df['sentence_sentiment'][x])
            table["feature"].append(df['feature'][x])
            table["weight"].append(df['weight'][x])
            table["rating"].append(df['rating'][x])

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('final_file_combined_features_with_app_name.csv', index = False)

# %%
data = pd.read_csv('final_file_combined_features_with_app_name.csv') 
df = pd.DataFrame(data, columns=['app_name', 'r_id', 'review', 'review_sentiment', 's_id', 'sentence', 'sentence_sentiment', 'feature', 'weight', 'rating'])

# %%
len(df)

# %%
app_name = df['app_name'].to_list()
rating = df['rating'].to_list()
review_sentiment = df['review_sentiment'].to_list()

# %%
# d = doordash
d_freq = d_n_total_score_1 = d_n_total_score_3 = d_n_total_score_5 = d_p_total_score_1 = d_p_total_score_3 = d_p_total_score_5 = 0
# u = ubereats
u_freq = u_n_total_score_1 = u_n_total_score_5 = u_p_total_score_1 = u_p_total_score_5 = 0
# g = grubhub
g_freq = g_n_total_score_1 = g_n_total_score_5 = g_p_total_score_1 = g_p_total_score_5 = 0
# p = postmates
p_freq = p_n_total_score_1 = p_n_total_score_5 = p_p_total_score_1 = p_p_total_score_5 = 0


# 1-3
# 4-5
for x in range(len(df)):
    if app_name[x] == 'doordash':
        d_freq = d_freq + 1
        if rating[x] == 1:
            if review_sentiment[x] < 0:
                d_n_total_score_1 = d_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_1 = d_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] == 5:
            if review_sentiment[x] < 0:
                d_n_total_score_5 = d_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_5 = d_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'ubereats':
        u_freq = u_freq + 1
        if rating[x] == 1:
            if review_sentiment[x] < 0:
                u_n_total_score_1 = u_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_1 = u_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] == 5:
            if review_sentiment[x] < 0:
                u_n_total_score_5 = u_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_5 = u_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'postmates':
        p_freq = p_freq + 1
        if rating[x] == 1:
            if review_sentiment[x] < 0:
                p_n_total_score_1 = p_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_1 = p_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] == 5:
            if review_sentiment[x] < 0:
                p_n_total_score_5 = p_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_5 = p_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'grubhub':
        g_freq = g_freq + 1
        if rating[x] == 1:
            if review_sentiment[x] < 0:
                g_n_total_score_1 = g_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_1 = g_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] == 5:
            if review_sentiment[x] < 0:
                g_n_total_score_5 = g_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_5 = g_p_total_score_5 + abs(review_sentiment[x])              

# doordash
d_n_1 = d_n_total_score_1/d_freq
d_n_5 = d_n_total_score_5/d_freq
d_p_1 = d_p_total_score_1/d_freq
d_p_5 = d_p_total_score_5/d_freq

d_dissatisfaction = d_p_1/d_n_1
d_satisfaction = d_n_5/d_p_5


# ubereats
u_n_1 = u_n_total_score_1/u_freq
u_n_5 = u_n_total_score_5/u_freq
u_p_1 = u_p_total_score_1/u_freq
u_p_5 = u_p_total_score_5/u_freq

u_dissatisfaction = u_p_1/u_n_1
u_satisfaction = u_n_5/u_p_5


# postmates
p_n_1 = p_n_total_score_1/p_freq
p_n_5 = p_n_total_score_5/p_freq
p_p_1 = p_p_total_score_1/p_freq
p_p_5 = p_p_total_score_5/p_freq

p_dissatisfaction = p_p_1/p_n_1
p_satisfaction = p_n_5/p_p_5

# grubhub
g_n_1 = g_n_total_score_1/g_freq
g_n_5 = g_n_total_score_5/g_freq
g_p_1 = g_p_total_score_1/g_freq
g_p_5 = g_p_total_score_5/g_freq

g_dissatisfaction = g_p_1/g_n_1
g_satisfaction = g_n_5/g_p_5

# %%
df
# Out:
#         app_name  r_id                                             review  \
# 0        grubhub   203  They force you to work on a schedule otherwise...
# 1        grubhub   203  This company should not be in business for bre...
# 2       doordash  1121  I have been both a consumer and dasher and it'...
# 3       doordash  1121  As a previous dasher I know that it is hard to...
# 4       doordash  1121  Most consumers are reluctant to leave a tip an...
# ...          ...   ...                                                ...
# 49745   ubereats   851  The tip for the person who delivered to wrong ...
# 49746   ubereats   851  Had to reorder and now an hour and a half late...
# 49747   ubereats   851                              Not worth it anymore.
# 49748  postmates  1097  The first delivery the driver did not knock on...
# 49749  postmates  1097  Cold coffee..The second order time or order wa...
#
#        review_sentiment  s_id  \
# 0              0.000000  1402
# ...

# %%
df_filtered = df.drop_duplicates('feature')
print(len(df_filtered))
# Out:
# 25

# %%
#BEN EKLEDIM
#CREATE Dissatisfaction, satisfaction, neutral, frequency lists
dissatisfaction = []
satisfaction = []
neutral = []


frequency = df.pivot_table(columns=['feature'], aggfunc='size').tolist()
print (len(frequency))



for x in range(len(df_filtered)):
    if rating[x] == 1 or rating[x] == 2:
        if review_sentiment[x] < 0:
            d_n_total_score_1 = d_n_total_score_1 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            d_p_total_score_1 = d_p_total_score_1 + abs(review_sentiment[x])
        d_n_1 = d_n_total_score_1
        d_p_1 = d_p_total_score_1
        dissatisfaction.append(d_p_1/d_n_1)
        satisfaction.append(0)
        neutral.append(0)
    elif rating[x] == 5 or rating[x] == 4:
        if review_sentiment[x] < 0:
            d_n_total_score_5 = d_n_total_score_5 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            d_p_total_score_5 = d_p_total_score_5 + abs(review_sentiment[x])
        d_n_5 = d_n_total_score_5
        d_p_5 = d_p_total_score_5
        satisfaction.append(d_p_5/d_n_5)
        dissatisfaction.append(0)
        neutral.append(0)
    elif rating[x] == 3:
        if review_sentiment[x] < 0:
            d_n_total_score_3 = d_n_total_score_3 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            d_p_total_score_3 = d_p_total_score_3 + abs(review_sentiment[x])
        d_n_3 = d_n_total_score_3
        d_p_3 = d_p_total_score_3
        if d_n_3 != 0:
            neutral.append(d_p_3/d_n_3)
        else:
            neutral.append(0)
        satisfaction.append(0)
        dissatisfaction.append(0)

print(len(dissatisfaction))
print(len(satisfaction))
print(len(neutral))
sum_sat = (len(dissatisfaction) + len(satisfaction) + len(neutral))
if sum_sat == len(df_filtered):
    print(True)
else:
    print(False)
diff = len(df) - sum_sat
print(diff)
# Out:
# 25
# 25
# 25
# 25
# False
# 862

# %%
#BEN EKLEDIM
#CREATE TABLE FOR DF
table = {'feature': [], 'dissatisfaction': [], 'satisfaction': [], 'neutral': [], 'frequency': []}

for x in range(len(df_filtered)):
    table["feature"].append(df['feature'][x])
    table["dissatisfaction"].append(dissatisfaction[x])
    table["satisfaction"].append(satisfaction[x])
    table["neutral"].append(neutral[x])
    table["frequency"].append(frequency[x])

# %%
#BEN EKLEDIM
#CREATE FILE WITH DF
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('features_satisfaction_dissatisfaction_neutral_scaled_with_apps_manual.csv', index = False)

# %%
data_f = pd.read_csv('features_satisfaction_dissatisfaction_neutral_scaled_with_apps_manual.csv') 
dfF = pd.DataFrame(data_f, columns=['feature', 'dissatisfaction', 'satisfaction', 'neutral', 'frequency'])

# %%
dfF
# Out:
#                    feature  dissatisfaction  satisfaction  neutral  frequency
# 0   independent contractor         0.785145      0.000000        0         27
# 1   independent contractor         0.785145      0.000000        0         57
# 2   independent contractor         0.000000      5.065559        0         16
# 3   independent contractor         0.000000      5.046022        0         20
# 4   independent contractor         0.000000      5.046887        0         13
# 5   independent contractor         0.000000      5.050253        0         19
# 6   independent contractor         0.000000      5.056985        0         52
# 7   independent contractor         0.000000      5.056985        0         36
# 8   independent contractor         0.000000      5.051671        0         85
# 9   independent contractor         0.000000      5.061759        0         48
# 10  independent contractor         0.000000      5.061759        0         61
# ...

# %%
table = {'feature': [], 'dissatisfaction': [], 'satisfaction': [], 'neutral': [], 'frequency': [], 'doordash_e': [], 'd_dissatisfaction':[], 'd_satisfaction': [], 'ubereats_e': [], 'u_dissatisfaction':[], 'u_satisfaction': [], 'grubhub_e': [], 'g_dissatisfaction':[], 'g_satisfaction': [], 'postmates_e': [], 'p_dissatisfaction':[], 'p_satisfaction': []}

for x in range(len(dfF)):
    table["feature"].append(dfF['feature'][x])
    table["dissatisfaction"].append(dfF['dissatisfaction'][x])
    table["satisfaction"].append(dfF['satisfaction'][x])
    table["neutral"].append(dfF['neutral'][x])
    table["frequency"].append(dfF['frequency'][x])
    table["doordash_e"].append(dfF['doordash_e'][x])
    table["d_dissatisfaction"].append(d_dissatisfaction)
    table["d_satisfaction"].append(d_satisfaction)
    table["ubereats_e"].append(dfF['ubereats_e'][x])
    table["u_dissatisfaction"].append(u_dissatisfaction)
    table["u_satisfaction"].append(u_satisfaction)
    
    table["grubhub_e"].append(dfF['grubhub_e'][x])
    table["g_dissatisfaction"].append(g_dissatisfaction)
    table["g_satisfaction"].append(g_satisfaction)
    
    table["postmates_e"].append(dfF['postmates_e'][x])
    table["p_dissatisfaction"].append(p_dissatisfaction)
    table["p_satisfaction"].append(p_satisfaction)

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('features_diss_sati_overall_diss_sati.csv', index = False)

# %% [markdown]
# # Remove the unrelated sentences

# %%
data_s = pd.read_csv('final_file_combined_features_with_app_name_labeled.csv') 
dfS = pd.DataFrame(data_s, columns=['app_name', 'r_id', 'review', 'review_sentiment', 's_id', 'sentence', 'functional_sentence', 'sentence_sentiment', 'feature', 'weight', 'rating'])

# %%
len(dfS)

# %%
# remove duplicated records of the same review
# dfS = dfS.drop_duplicates(subset=['r_id', 'review', 'review_sentiment'], keep="first")
# dfS = dfS.reset_index(drop=True)

# %%
# Remove non functional sentences
functional = dfS['functional_sentence'].to_list()
dfS.drop(dfS[dfS['functional_sentence'] == 0].index, inplace = True)
dfS = dfS.reset_index(drop=True)

# %%
s_id_to_check = dfS['s_id'].to_list()
sent_to_check = dfS['sentence'].to_list()

# %%
len(sent_to_check)

# %%
features = dfS['feature'].to_list()

# %%
features

# %% [markdown]
# # TF-IDF

# %%
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd

# %%
# Get tagged sentences 
dataC = pd.read_csv('cleaned_tagged_sentences.csv') 
dfC = pd.DataFrame(dataC, columns=['s_id', 'new_tagged_sentences'])

# %%
sent_list = dfC['new_tagged_sentences'].to_list()
id_list = dfC['s_id'].to_list()

# %%
len(sent_list)
# Out:
# 8282

# %%
for x in range(len(sent_list)):
    if re.search('costumer service', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('costumer service', 'customer service')
        print("New:",sent_list[x])
    elif re.search('customer support', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('customer support', 'customer service')
        print("New:",sent_list[x])
    elif re.search('call center', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('call center', 'customer service')
        print("New:",sent_list[x])  
    elif re.search('support team', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('support team', 'customer service')
        print("New:",sent_list[x]) 
    elif re.search('customer care', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('customer care', 'customer service')
        print("New:",sent_list[x]) 
        
    if re.search('payment option', sent_list[x]):
        print("Old:", sent_list[x])
        string = sent_list[x]
        sent_list[x] = string.replace('payment option', 'payment method')
        print("New:", sent_list[x])
# Out:
# Old: i notice charge report customer care i get email say move inquiry priority due serious nature concern be contact
# New: i notice charge report customer service i get email say move inquiry priority due serious nature concern be contact
# Old: thick accent loud call center
# New: thick accent loud customer service
# Old: yes money get refund i contact customer support
# New: yes money get refund i contact customer service
# Old: i get touch customer support inform take day be refund order be create place be able make time i have figure different delivery i be go risk food be lose terrible service
# New: i get touch customer service inform take day be refund order be create place be able make time i have figure different delivery i be go risk food be lose terrible service
# ...

# %%
# Get the tagged sentences of my current sentences (that have functional sentences)
for x in range(len(dfS)):
    for y in range(len(dfC)):
        if s_id_to_check[x] == id_list[y]:
            print('OLD', sent_to_check[x])
            sent_to_check[x] = sent_list[y]
            print('TAGGED', sent_to_check[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[155], line 2
#       1 # Get the tagged sentences of my current sentences (that have functional sentences)
# ----> 2 for x in range(len(dfS)):
#       3     for y in range(len(dfC)):
#       4         if s_id_to_check[x] == id_list[y]:
#
# NameError: name 'dfS' is not defined

# %%
for x in range(len(sent_to_check)):
    if re.search('costumer service', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('costumer service', 'customer service')
        print("New:",sent_to_check[x])
    elif re.search('customer support', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('customer support', 'customer service')
        print("New:",sent_to_check[x])
    elif re.search('call center', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('call center', 'customer service')
        print("New:",sent_to_check[x])  
    elif re.search('support team', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('support team', 'customer service')
        print("New:",sent_to_check[x]) 
    elif re.search('customer care', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('customer care', 'customer service')
        print("New:",sent_to_check[x]) 
        
    if re.search('payment option', sent_to_check[x]):
        print("Old:", sent_to_check[x])
        string = sent_to_check[x]
        sent_to_check[x] = string.replace('payment option', 'payment method')
        print("New:", sent_to_check[x])

# %%
sent_to_check

# %%
len(sent_to_check)

# %%
# Getting bigrams 
vectorizer = CountVectorizer(ngram_range =(2, 2))
X1 = vectorizer.fit_transform(sent_to_check) 
features = (vectorizer.get_feature_names())
print("\n\nX1 : \n", X1.toarray())

# %%
# Applying TFIDF
vectorizer = TfidfVectorizer(ngram_range = (2, 2))
X2 = vectorizer.fit_transform(sent_to_check)
scores = (X2.toarray())
print("\n\nScores : \n", scores)

# %%
sums = X2.sum(axis = 0)
data1 = []
for col, term in enumerate(features):
    data1.append( (term, sums[0, col] ))
ranking = pd.DataFrame(data1, columns = ['term', 'rank'])
words = (ranking.sort_values('rank', ascending = False))
print ("\n\nWords : \n", words)

# %%
feature_to_match = words['term'].to_list()
new_weight = words['rank'].to_list()

# %%
feature_to_match

# %%
table = {"app_name": [], "r_id": [], "review": [], "review_sentiment": [], "s_id": [], "sentence": [], "sentence_sentiment": [], "functional_sentence": [], "feature": [], 'weight': [], 'rating': []}

for y in range(len(words)):
    for x in range(len(dfS)):
        if feature_to_match[y] == features[x]:
            table["app_name"].append(dfS['app_name'][x])
            table["r_id"].append(dfS['r_id'][x])
            table["review"].append(dfS['review'][x])
            table["review_sentiment"].append(dfS['review_sentiment'][x])
            table["s_id"].append(dfS['s_id'][x])
            table["sentence"].append(dfS['sentence'][x])
            table["sentence_sentiment"].append(dfS['sentence_sentiment'][x])
            table["functional_sentence"].append(dfS['functional_sentence'][x])
            table["feature"].append(dfS['feature'][x])
#             table["weight"].append(dfS['weight'][x])
            table["weight"].append(new_weight[y])
            table["rating"].append(dfS['rating'][x])

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('features_new_weight.csv', index = False)

# %% [markdown]
# # Save each feature with its weight

# %%
data_w = pd.read_csv('features_new_weight.csv') 
dfW = pd.DataFrame(data_w, columns=['feature','weight'])
# I counted the unique feature manually from the file = 27

# %%
dfW.drop_duplicates(inplace=True)

# %%
dfW = dfW.reset_index(drop=True)

# %%
len(dfW)

# %% [markdown]
# # App overall dissatisfaction and satisfaction

# %%
data = pd.read_csv('features_new_weight.csv') 
df = pd.DataFrame(data, columns=['app_name', 'r_id', 'review', 'review_sentiment', 's_id', 'sentence', 'sentence_sentiment', 'feature', 'weight', 'rating'])

# %%
len(df)

# %%
# remove duplicated records of the same review
df = df.drop_duplicates(subset=['r_id', 'review', 'review_sentiment'], keep="first")
df = df.reset_index(drop=True)

# %%
app_name = df['app_name'].to_list()
rating = df['rating'].to_list()
review_sentiment = df['review_sentiment'].to_list()

# %%
# d = doordash
d_freq = d_n_total_score_1 = d_n_total_score_5 = d_p_total_score_1 = d_p_total_score_5 = 0
# u = ubereats
u_freq = u_n_total_score_1 = u_n_total_score_5 = u_p_total_score_1 = u_p_total_score_5 = 0
# g = grubhub
g_freq = g_n_total_score_1 = g_n_total_score_5 = g_p_total_score_1 = g_p_total_score_5 = 0
# p = postmates
p_freq = p_n_total_score_1 = p_n_total_score_5 = p_p_total_score_1 = p_p_total_score_5 = 0

# 1-3
# 4-5
for x in range(len(df)):
    if app_name[x] == 'doordash':
        d_freq = d_freq + 1
        if rating[x] == 1:
            if review_sentiment[x] < 0:
                d_n_total_score_1 = d_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_1 = d_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] >=4 and rating[x] <= 5:
            if review_sentiment[x] < 0:
                d_n_total_score_5 = d_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_5 = d_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'ubereats':
        u_freq = u_freq + 1
        if rating[x] >= 1 and rating[x] <=3:
            if review_sentiment[x] < 0:
                u_n_total_score_1 = u_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_1 = u_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] >=4 and rating[x] <= 5:
            if review_sentiment[x] < 0:
                u_n_total_score_5 = u_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_5 = u_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'postmates':
        p_freq = p_freq + 1
        if rating[x] >= 1 and rating[x] <=3:
            if review_sentiment[x] < 0:
                p_n_total_score_1 = p_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_1 = p_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] >=4 and rating[x] <= 5:
            if review_sentiment[x] < 0:
                p_n_total_score_5 = p_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_5 = p_p_total_score_5 + abs(review_sentiment[x])
    elif app_name[x] == 'grubhub':
        g_freq = g_freq + 1
        if rating[x] >= 1 and rating[x] <=3:
            if review_sentiment[x] < 0:
                g_n_total_score_1 = g_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_1 = g_p_total_score_1 + abs(review_sentiment[x])
        elif rating[x] >=4 and rating[x] <= 5:
            if review_sentiment[x] < 0:
                g_n_total_score_5 = g_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_5 = g_p_total_score_5 + abs(review_sentiment[x])

                
# doordash
if d_freq != 0:
    d_n_1 = d_n_total_score_1/d_freq
    d_n_5 = d_n_total_score_5/d_freq
    d_p_1 = d_p_total_score_1/d_freq
    d_p_5 = d_p_total_score_5/d_freq
else: 
    d_n_1 = 0
    d_n_5 = 0
    d_p_1 = 0
    d_p_5 = 0
    
if d_n_1 != 0:
    d_dissatisfaction = d_p_1/d_n_1
else:
    d_dissatisfaction = 0
    
if d_p_5 != 0:
    d_satisfaction = d_n_5/d_p_5
else:
    d_satisfaction = 0

# ubereats
if u_freq != 0:
    u_n_1 = u_n_total_score_1/u_freq
    u_n_5 = u_n_total_score_5/u_freq
    u_p_1 = u_p_total_score_1/u_freq
    u_p_5 = u_p_total_score_5/u_freq
else: 
    u_n_1 = 0
    u_n_5 = 0
    u_p_1 = 0
    u_p_5 = 0

if u_n_1 != 0:
    u_dissatisfaction = u_p_1/u_n_1
else:
    u_dissatisfaction = 0

if u_p_5 != 0:
    u_satisfaction = u_n_5/u_p_5
else: 
    u_satisfaction = 0

# postmates
if p_freq != 0:
    p_n_1 = p_n_total_score_1/p_freq
    p_n_5 = p_n_total_score_5/p_freq
    p_p_1 = p_p_total_score_1/p_freq
    p_p_5 = p_p_total_score_5/p_freq
else: 
    p_n_1 = 0
    p_n_5 = 0
    p_p_1 = 0
    p_p_5 = 0   

if p_n_1 != 0:
    p_dissatisfaction = p_p_1/p_n_1
else:
    p_dissatisfaction = 0

if p_p_5 != 0:
    p_satisfaction = p_n_5/p_p_5
else: 
    p_satisfaction = 0
    
    
# grubhub
if g_freq != 0:
    g_n_1 = g_n_total_score_1/g_freq
    g_n_5 = g_n_total_score_5/g_freq
    g_p_1 = g_p_total_score_1/g_freq
    g_p_5 = g_p_total_score_5/g_freq
else:
    g_n_1 = 0
    g_n_5 = 0
    g_p_1 = 0
    g_p_5 = 0
    
if g_n_1 != 0:
    g_dissatisfaction = g_p_1/g_n_1
else: 
    g_dissatisfaction = 0

if g_p_5 != 0:
    g_satisfaction =g_n_5/g_p_5
else:
    g_satisfaction = 0

# %%
data_f = pd.read_csv('features_satisfaction_dissatisfaction_neutral_scaled_with_apps_manual.csv') 
dfF = pd.DataFrame(data_f, columns=['feature', 'doordash_e', 'ubereats_e', 'grubhub_e', 'postmates_e'])

# %%
table = {'feature': [], 'doordash_e': [], 'd_dissatisfaction':[], 'd_satisfaction': [], 'ubereats_e': [], 'u_dissatisfaction':[], 'u_satisfaction': [], 'grubhub_e': [], 'g_dissatisfaction':[], 'g_satisfaction': [], 'postmates_e': [], 'p_dissatisfaction':[], 'p_satisfaction': []}

for x in range(len(dfF)):
    table["feature"].append(dfF['feature'][x])
    
    table["doordash_e"].append(dfF['doordash_e'][x])
    table["d_dissatisfaction"].append(d_dissatisfaction)
    table["d_satisfaction"].append(d_satisfaction)
    
    table["ubereats_e"].append(dfF['ubereats_e'][x])
    table["u_dissatisfaction"].append(u_dissatisfaction)
    table["u_satisfaction"].append(u_satisfaction)
    
    table["grubhub_e"].append(dfF['grubhub_e'][x])
    table["g_dissatisfaction"].append(g_dissatisfaction)
    table["g_satisfaction"].append(g_satisfaction)
    
    table["toyou_e"].append(dfF['toyou_e'][x])
    table["p_dissatisfaction"].append(p_dissatisfaction)
    table["p_satisfaction"].append(p_satisfaction)

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('features_overall_dissatisfaction_satisfaction.csv', index = False)

# %% [markdown]
# # Feature Dissatisfaction and Satisfaction

# %%
features_list = dfW['feature'].to_list()
weight = dfW['weight'].to_list()

# %%
data = pd.read_csv('features_new_weight.csv') 
df = pd.DataFrame(data, columns=['feature',  'sentence_sentiment'])

# %%
feature_to_match = df['feature'].to_list()
feature_sentiment = df['sentence_sentiment'].to_list()

# %%
features_list

# %%
feature_satisfaction = []
dissatisfaction = []
feature_neutral = []
freq = []
for x in range(len(features_list)):
    frequency = n_frequency = n_total_score = p_frequency = p_total_score = np_frequency = np_total_score = 0
    for y in range(len(feature_to_match)):
        if features_list[x] == feature_to_match[y]:
            frequency = frequency + 1
            if feature_sentiment[y] < 0:
                n_frequency = n_frequency + 1
                n_total_score = n_total_score + abs(feature_sentiment[y])
            elif feature_sentiment[y] > 0:
                p_frequency = p_frequency + 1
                p_total_score = p_total_score + feature_sentiment[y]
            elif feature_sentiment[y] == 0:
                np_frequency = np_frequency + 1
                np_total_score = np_total_score + 1
    freq.insert(x, frequency)
    
    if n_frequency > 0:
        n_avg = float(n_total_score*weight[x])/frequency
        dissatisfaction.insert(x, n_avg)
    elif n_frequency == 0:
        dissatisfaction.insert(x, 0)
        
    if p_frequency > 0:
        p_avg = float(p_total_score*weight[x])/frequency
        feature_satisfaction.insert(x, p_avg)
    elif p_frequency == 0:
        feature_satisfaction.insert(x, 0)
    
    if np_frequency > 0:
#         print(np_frequency)
        np_avg = float(np_total_score*weight[x])/frequency
        feature_neutral.insert(x, np_avg)
    elif np_frequency == 0:
        feature_neutral.insert(x, 0)

# %%
table = {"feature": [], "dissatisfaction": [], "satisfaction": [], "neutral": [], "frequency": []}

for x in range(len(features_list)):
    table["feature"].append(features_list[x])
    table["dissatisfaction"].append(dissatisfaction[x])
    table["satisfaction"].append(feature_satisfaction[x])
    table["neutral"].append(feature_neutral[x])
    table["frequency"].append(freq[x])

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('features_dissatisfaction_satisfaction_neutral_NEW.csv', index = False)

# %% [markdown]
# # Combine overall diss/sati with features diss/sati

# %%
# Drop the non-sensible features
dataO = pd.read_csv('features_overall_dissatisfaction_satisfaction.csv') 
dfO = pd.DataFrame(dataO, columns=['feature','doordash_e', 'd_dissatisfaction', 'd_satisfaction', 'ubereats_e', 'u_dissatisfaction', 'u_satisfaction', 'grubhub_e', 'g_dissatisfaction', 'g_satisfaction', 'postmates_e', 'p_dissatisfaction', 'p_satisfaction'])

# %%
dfO = dfO.fillna(0)

# %%
for o in range(len(dfO)):
    if dfO['doordash_e'][o] == 0 and dfO['ubereats_e'][o] == 0 and dfO['grubhub_e'][o] == 0 and dfO['postmates_e'][o] == 0:
        dfO.drop(o, inplace=True)

# %%
dfO = dfO.reset_index(drop=True)

# %%
featureO = dfO['feature'].to_list()

# %%
dataN = pd.read_csv('features_dissatisfaction_satisfaction_neutral_NEW.csv') 
dfN = pd.DataFrame(dataN, columns=['feature','dissatisfaction', 'satisfaction', 'neutral', 'frequency'])

# %%
featureN = dfN['feature'].to_list()

# %%
len(dfO)

# %%
data = pd.read_csv('functional_FINAL_DATA.csv') 
dfNew = pd.DataFrame(data, columns=['app_name', 'r_id', 'review', 'review_sentiment', 's_id', 'sentence', 'sentence_sentiment', 'feature', 'weight', 'rating'])

# %%
rating = dfNew['rating'].to_list()
app_name = dfNew['app_name'].to_list()
review_sentiment = dfNew['review_sentiment'].to_list()
feature_dissatisfaction = []
feature_satisfaction = []
feature_neutral = []
feature = []

feature_frequency = dfNew.pivot_table(columns=['feature'], aggfunc='size').tolist()

dfNew = dfNew.drop_duplicates('feature')
dfNew = dfNew.reset_index(drop=True)






# f = feature
f_freq = f_n_total_score_1 = f_n_total_score_3 = f_p_total_score_3 = f_n_total_score_5 = f_p_total_score_1 = f_p_total_score_5 = 0
# d = doordash
d_freq = d_n_total_score_1 = d_n_total_score_5 = d_p_total_score_1 = d_p_total_score_5 = 0
# u = ubereats
u_freq = u_n_total_score_1 = u_n_total_score_5 = u_p_total_score_1 = u_p_total_score_5 = 0
# g = grubhub
g_freq = g_n_total_score_1 = g_n_total_score_5 = g_p_total_score_1 = g_p_total_score_5 = 0
# p = postmates
p_freq = p_n_total_score_1 = p_n_total_score_5 = p_p_total_score_1 = p_p_total_score_5 = 0

for x in range(len(dfNew)):
    if rating[x] == 1 or rating[x] == 2:
        if review_sentiment[x] < 0:
            f_n_total_score_1 = f_n_total_score_1 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            f_p_total_score_1 = f_p_total_score_1 + abs(review_sentiment[x])
        f_n_1 = f_n_total_score_1
        f_p_1 = f_p_total_score_1
        if f_n_1 != 0:
            feature_dissatisfaction.append(f_p_1/f_n_1)
        feature_satisfaction.append(0)
        feature_neutral.append(0)
    elif rating[x] == 5 or rating[x] == 4:
        if review_sentiment[x] < 0:
            f_n_total_score_5 = f_n_total_score_5 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            f_p_total_score_5 = f_p_total_score_5 + abs(review_sentiment[x])
        f_n_5 = f_n_total_score_5
        f_p_5 = f_p_total_score_5
        if f_n_5 != 0:
            feature_satisfaction.append(f_p_5/f_n_5)
        feature_dissatisfaction.append(0)
        feature_neutral.append(0)
    elif rating[x] == 3:
        if review_sentiment[x] < 0:
            f_n_total_score_3 = f_n_total_score_3 + abs(review_sentiment[x])
        if review_sentiment[x] > 0:
            f_p_total_score_3 = f_p_total_score_3 + abs(review_sentiment[x])
        f_n_3 = f_n_total_score_3
        f_p_3 = f_p_total_score_3
        if f_n_3 != 0:
            feature_neutral.append(f_p_3/f_n_3)
        feature_satisfaction.append(0)
        feature_dissatisfaction.append(0)


d_satisfaction = []
d_dissatisfaction = []
u_satisfaction = []
u_dissatisfaction = []
g_satisfaction = []
g_dissatisfaction = []
p_satisfaction = []
p_dissatisfaction = []

# 1-3
# 4-5
for x in range(len(dfNew)):
    if app_name[x] == 'doordash':
        d_freq = d_freq + 1
        if rating[x] == 1 or rating[x] == 2:
            if review_sentiment[x] < 0:
                d_n_total_score_1 = d_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_1 = d_p_total_score_1 + abs(review_sentiment[x])
            d_n_1 = d_n_total_score_1/d_freq
            d_p_1 = d_p_total_score_1/d_freq
            if d_n_1 != 0:
                d_dissatisfaction.append(d_p_1/d_n_1)
            else:
                d_dissatisfaction.append(0)
            d_satisfaction.append(0)
        elif rating[x] == 5 or rating[x] == 4:
            if review_sentiment[x] < 0:
                d_n_total_score_5 = d_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                d_p_total_score_5 = d_p_total_score_5 + abs(review_sentiment[x])
            d_n_5 = f_n_total_score_5/d_freq
            d_p_5 = f_p_total_score_5/d_freq
            if d_n_5 != 0:
                d_satisfaction.append(d_p_5/d_n_5)
            else:
                d_satisfaction.append(0)
            d_dissatisfaction.append(0)
    elif app_name[x] == 'ubereats':
        u_freq = u_freq + 1
        if rating[x] == 1 or rating[x] == 2:
            if review_sentiment[x] < 0:
                u_n_total_score_1 = u_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_1 = u_p_total_score_1 + abs(review_sentiment[x])
            u_n_1 = u_n_total_score_1/u_freq
            u_p_1 = u_p_total_score_1/u_freq
            if u_n_1 != 0:
                u_dissatisfaction.append(u_p_1/u_n_1)
            else:
                u_dissatisfaction.append(0)
            u_satisfaction.append(0)
        elif rating[x] == 5 or rating[x] == 4:
            if review_sentiment[x] < 0:
                u_n_total_score_5 = u_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                u_p_total_score_5 = u_p_total_score_5 + abs(review_sentiment[x])
            u_n_5 = u_n_total_score_5/u_freq
            u_p_5 = u_p_total_score_5/u_freq
            if u_n_5 != 0:
                u_satisfaction.append(u_p_5/u_n_5)
            else:
                u_satisfaction.append(0)
            u_dissatisfaction.append(0)
    elif app_name[x] == 'postmates':
        p_freq = p_freq + 1
        if rating[x] == 1 or rating[x] == 2:
            if review_sentiment[x] < 0:
                p_n_total_score_1 = p_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_1 = p_p_total_score_1 + abs(review_sentiment[x])
            p_n_1 = u_n_total_score_1/p_freq
            p_p_1 = u_p_total_score_1/p_freq
            if p_n_1 != 0:
                p_dissatisfaction.append(p_p_1/p_n_1)
            else:
                p_dissatisfaction.append(0)
            p_satisfaction.append(0)
        elif rating[x] == 5 or rating[x] == 4:
            if review_sentiment[x] < 0:
                p_n_total_score_5 = p_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                p_p_total_score_5 = p_p_total_score_5 + abs(review_sentiment[x])
            p_n_5 = p_n_total_score_5/p_freq
            p_p_5 = p_p_total_score_5/p_freq
            if p_n_5 != 0:
                p_satisfaction.append(p_p_5/p_n_5)
            else:
                p_satisfaction.append(0)
            p_dissatisfaction.append(0)
    elif app_name[x] == 'grubhub':
        g_freq = g_freq + 1
        if rating[x] == 1 or rating[x] == 2:
            if review_sentiment[x] < 0:
                g_n_total_score_1 = g_n_total_score_1 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_1 = g_p_total_score_1 + abs(review_sentiment[x])
            g_n_1 = g_n_total_score_1/g_freq
            g_p_1 = g_p_total_score_1/g_freq
            if g_n_1 != 0:
                g_dissatisfaction.append(g_p_1/g_n_1)
            else:
                g_dissatisfaction.append(0)
            g_satisfaction.append(0)
        elif rating[x] == 5 or rating[x] == 4:
            if review_sentiment[x] < 0:
                g_n_total_score_5 = g_n_total_score_5 + abs(review_sentiment[x])
            if review_sentiment[x] > 0:
                g_p_total_score_5 = g_p_total_score_5 + abs(review_sentiment[x])
            g_n_5 = g_n_total_score_5/g_freq
            g_p_5 = g_p_total_score_5/g_freq
            if g_n_5 != 0:
                g_satisfaction.append(g_p_5/g_n_5)
            else:
                g_satisfaction.append(0)
            g_dissatisfaction.append(0)
            
print(len(p_dissatisfaction), len(d_dissatisfaction), len(u_dissatisfaction), len(g_dissatisfaction))
print(len(feature_dissatisfaction), len(feature_satisfaction), len(feature_neutral), len(feature_frequency))
# Out:
# 475
# 25 74 162 179
# 470 467 474 475

# %%
value = len(dfNew)
for x in range(value-len(p_dissatisfaction)):
    p_dissatisfaction.append(0)
    p_satisfaction.append(0)
for x in range(value-len(d_dissatisfaction)):
    d_dissatisfaction.append(0)
    d_satisfaction.append(0)
for x in range(value-len(g_dissatisfaction)):
    g_dissatisfaction.append(0)
    g_satisfaction.append(0)
for x in range(value-len(u_dissatisfaction)):
    u_dissatisfaction.append(0)
    u_satisfaction.append(0)
for x in range(value-len(feature_dissatisfaction)):
    feature_dissatisfaction.append(0)
for x in range(value-len(feature_satisfaction)):
    feature_satisfaction.append(0)
for x in range(value-len(feature_neutral)):
    feature_neutral.append(0)


print(len(p_dissatisfaction), len(d_dissatisfaction), len(u_dissatisfaction), len(g_dissatisfaction))
print(len(feature_dissatisfaction), len(feature_satisfaction), len(feature_neutral), len(feature_frequency))
# Out:
# 475 475 475 475
# 475 475 475 475

# %%
print(len(dfNew['feature']))
# Out:
# 475

# %%
table = {'feature': [], "feature_dissatisfaction": [], "feature_satisfaction": [], "feature_neutral": [], "feature_frequency": [], 'd_dissatisfaction':[], 'd_satisfaction': [], 'u_dissatisfaction':[], 'u_satisfaction': [], 'g_dissatisfaction':[], 'g_satisfaction': [], 'p_dissatisfaction':[], 'p_satisfaction': []}

for x in range(len(dfNew)):
    table["feature"].append(dfNew['feature'][x])
    table["feature_dissatisfaction"].append(feature_dissatisfaction[x])
    table["feature_satisfaction"].append(feature_satisfaction[x])
    table["feature_neutral"].append(feature_neutral[x])
    table["feature_frequency"].append(feature_frequency[x])
                    
    table["d_dissatisfaction"].append(d_dissatisfaction[x])
    table["d_satisfaction"].append(d_satisfaction[x])
      
    table["u_dissatisfaction"].append(u_dissatisfaction[x])
    table["u_satisfaction"].append(u_satisfaction[x])

    table["g_dissatisfaction"].append(g_dissatisfaction[x])
    table["g_satisfaction"].append(g_satisfaction[x])

    table["p_dissatisfaction"].append(p_dissatisfaction[x])
    table["p_satisfaction"].append(p_satisfaction[x])

# %%
df=pd.DataFrame.from_dict(table,orient='index').transpose()
df.to_csv('FINAL_FINAL_DATA.csv', index = False)
